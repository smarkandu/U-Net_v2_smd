# %%
PYTHON_VERSION = "3.9"

# --- Update apt and install Python 3.9 ---
# !sudo apt-get update -y
# !sudo apt-get install -y python{PYTHON_VERSION} python{PYTHON_VERSION}-distutils

# --- Switch python3 to the new version ---
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.9 2

# Automatically set python3 to use python3.9
# !sudo update-alternatives --set python3 /usr/bin/python3.9

# --- Verify Python version ---
# !python --version

# --- Install pip for the new Python ---
# !wget https://bootstrap.pypa.io/get-pip.py -O get-pip.py
# !python get-pip.py

# --- Upgrade pip and install packages ---
# !python -m pip install --upgrade pip
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://cli.github.com/packages stable/main amd64 Packages [344 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# !rm -r unet_v2
# !ls -al
# !git clone https://github.com/smarkandu/U-Net_v2_smd.git
# Out:
# Cloning into 'U-Net_v2_smd'...
# remote: Enumerating objects: 1054, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 1054 (delta 17), reused 20 (delta 15), pack-reused 1027 (from 1)
# Receiving objects: 100% (1054/1054), 94.30 MiB | 32.10 MiB/s, done.
# Resolving deltas: 100% (429/429), done.

# %%
# !pwd
# !cat requirements.txt
# %cd U-Net_v2_smd
# !pip install -r requirements.txt
# Out:
# /content
# /content/U-Net_v2_smd
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.2/829.2 kB 26.0 MB/s  0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 163.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 105.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 183.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 55.1 MB/s  0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 MB 79.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 120.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 104.3 MB/s  0:00:00
# ...

# %%
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1YiGHLw4iTvKdvbT6MgwO9zcCv8zJ_Bnb
# !gdown https://drive.google.com/uc?id=1Y2z7FD5p5y31vkZwQQomXFRB0HutHyao
# !mkdir TrainSave
# !unzip TrainDataset.zip
# !unzip TestDataset.zip
# !mv ./TrainDataset/image/ ./TrainDataset/images/
# !pwd

# %%
# !python ./PolypSeg/Train.py --train_path TrainDataset/ --test_path TestDataset/ --train_save TrainSave/
# Out:
# /usr/local/lib/python3.9/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
# !ls -al ./TrainDataset/
# Out:
# total 152
# drwxr-xr-x  4 root root  4096 Mar 27  2023 .
# drwxr-xr-x 13 root root  4096 Oct 16 23:01 ..
# drwxr-xr-x  2 root root 69632 Mar 14  2020 image
# drwxr-xr-x  2 root root 69632 Mar 27  2023 masks
